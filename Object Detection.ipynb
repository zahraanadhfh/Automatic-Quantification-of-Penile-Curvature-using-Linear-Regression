# %% [markdown]
# # Import Drive

# %%
# Lakukan mounting ke Google Drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt comet_ml  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-253-g63555c8 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.4/166.8 GB disk)

# %%
# %cd '/content/yolov5'
# Out:
# /content/yolov5

# %% [markdown]
# ## YOLOv5x

# %%
# !python train.py --img 640 --batch 16 --epochs 50 --data '/content/gdrive/MyDrive/TREK-AI/data_train.yml' --weights yolov5x.pt
# Out:
# 2023-12-24 16:27:33.051057: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-24 16:27:33.051110: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-24 16:27:33.052418: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %% [markdown]
# model summary:
#
# 1.   precision: 1
# 2.   recall: 1
# 3.   mAP50: 0.995
# 4.   mAP50-95: 0.986

# %% [markdown]
# ## YOLOv5s

# %%
# !python train.py --img 640 --batch 16 --epochs 50 --data '/content/gdrive/MyDrive/TREK-AI/data_train.yml' --weights yolov5s.pt
# Out:
# 2023-12-09 14:41:46.763787: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-09 14:41:46.763858: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-09 14:41:46.763903: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %% [markdown]
# model summary:
#
#
# 1.   precision: 1
# 2.   recall: 1
# 3.   mAP50:  0.995
# 4.   mAP50-95: 0.98

# %% [markdown]
# ## YOLOv5n

# %%
# !python train.py --img 640 --batch 16 --epochs 50 --data '/content/gdrive/MyDrive/TREK-AI/data_train.yaml' --weights yolov5n.pt
# Out:
# 2023-12-09 23:55:48.499310: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-09 23:55:48.499445: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-09 23:55:48.499614: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %% [markdown]
# model summary:
#
# 1.   precision: 1
# 2.   recall: 1
# 3.   mAP50: 0.995
# 4.   mAP50-95: 0.965

# %% [markdown]
# ## YOLOv5m

# %%
# !python train.py --img 640 --batch 16 --epochs 50 --data '/content/gdrive/MyDrive/TREK-AI/data_train.yaml' --weights yolov5m.pt
# Out:
# 2023-12-03 13:56:31.868251: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-03 13:56:31.868311: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-03 13:56:31.868355: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %% [markdown]
# model summary:
#
# 1.   precision: 1
# 2.   recall: 1
# 3.   mAP50: 0.995
# 4.   mAP50-95: 0.983

# %% [markdown]
# ## YOLOv5l

# %%
# !python train.py --img 640 --batch 16 --epochs 50 --data '/content/gdrive/MyDrive/TREK-AI/data_train.yaml' --weights yolov5l.pt
# Out:
# 2023-12-03 14:41:39.137567: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-03 14:41:39.137622: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-03 14:41:39.137660: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %% [markdown]
# model summary:
#
# 1.   precision: 1
# 2.   recall: 1
# 3.   mAP50: 0.995
# 4.   mAP50-95: 0.985

# %%
# !python train.py --img 640 --batch 16 --epochs 50 --data '/content/gdrive/MyDrive/TREK-AI/data_train.yml' --weights yolov5x.pt
# Out:
# 2023-12-17 14:25:14.502119: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-17 14:25:14.502181: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-17 14:25:14.503605: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
